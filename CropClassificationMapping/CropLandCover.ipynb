# %%
# %pip install -U leafmap
# Out:
# Requirement already satisfied: leafmap in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.48.9)
# Requirement already satisfied: anywidget in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (0.9.13)
# Requirement already satisfied: bqplot in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (0.12.45)
# Requirement already satisfied: duckdb in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (1.3.2)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (0.17.0)
# Requirement already satisfied: gdown in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (5.2.0)
# Requirement already satisfied: geojson in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (3.1.0)
# Requirement already satisfied: geopandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (0.14.4)
# Requirement already satisfied: ipyevents in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (2.0.2)
# Requirement already satisfied: ipyfilechooser in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (0.6.0)
# Requirement already satisfied: ipyleaflet in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (0.19.2)
# Requirement already satisfied: ipyvuetify in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (1.11.3)
# Requirement already satisfied: ipywidgets in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (8.1.5)
# Requirement already satisfied: maplibre in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (0.3.5)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (3.9.2)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (1.26.4)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (2.1.4)
# Requirement already satisfied: plotly in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (5.24.1)
# Requirement already satisfied: pystac-client in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (0.9.0)
# Requirement already satisfied: python-box in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (7.3.2)
# Requirement already satisfied: scooby in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (0.10.1)
# Requirement already satisfied: whiteboxgui in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (2.3.0)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from leafmap) (2024.9.0)
# Requirement already satisfied: psygnal>=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from anywidget->leafmap) (0.11.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from anywidget->leafmap) (4.12.2)
# Requirement already satisfied: comm>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipywidgets->leafmap) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipywidgets->leafmap) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipywidgets->leafmap) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipywidgets->leafmap) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipywidgets->leafmap) (3.0.13)
# Requirement already satisfied: backcall in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.2.0)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.19.0)
# Requirement already satisfied: matplotlib-inline in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.1.6)
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (2.16.1)
# Requirement already satisfied: stack-data in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (4.8.0)
# Requirement already satisfied: appnope in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.1.3)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->leafmap) (0.2.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->leafmap) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->leafmap) (0.7.0)
# Requirement already satisfied: traittypes>=0.0.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from bqplot->leafmap) (0.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->leafmap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->leafmap) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->leafmap) (2023.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->leafmap) (1.16.0)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium->leafmap) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium->leafmap) (3.1.6)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium->leafmap) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium->leafmap) (2.1.3)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gdown->leafmap) (4.12.2)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gdown->leafmap) (3.18.0)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gdown->leafmap) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from beautifulsoup4->gdown->leafmap) (2.5)
# Requirement already satisfied: fiona>=1.8.21 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from geopandas->leafmap) (1.10.1)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from geopandas->leafmap) (24.2)
# Requirement already satisfied: pyproj>=3.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from geopandas->leafmap) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from geopandas->leafmap) (2.0.6)
# Requirement already satisfied: attrs>=19.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas->leafmap) (23.1.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas->leafmap) (2024.12.14)
# Requirement already satisfied: click~=8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas->leafmap) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas->leafmap) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas->leafmap) (0.7.2)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipyleaflet->leafmap) (0.19.2)
# Requirement already satisfied: ipyvue<2,>=1.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipyvuetify->leafmap) (1.11.2)
# Requirement already satisfied: eval-type-backport in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from maplibre->leafmap) (0.2.0)
# Requirement already satisfied: pydantic>=2.5.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from maplibre->leafmap) (2.9.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic>=2.5.3->maplibre->leafmap) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic>=2.5.3->maplibre->leafmap) (2.23.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->leafmap) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->leafmap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->leafmap) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->leafmap) (1.4.7)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->leafmap) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->leafmap) (3.1.4)
# Requirement already satisfied: tenacity>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from plotly->leafmap) (9.0.0)
# Requirement already satisfied: pystac>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap) (1.13.0)
# Requirement already satisfied: jsonschema~=4.18 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap) (4.19.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (0.10.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium->leafmap) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium->leafmap) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium->leafmap) (2.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests[socks]->gdown->leafmap) (1.7.1)
# Requirement already satisfied: executing>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap) (2.4.0)
# Requirement already satisfied: pure-eval in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap) (0.2.2)
# Requirement already satisfied: ipytree in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from whiteboxgui->leafmap) (0.2.2)
# Requirement already satisfied: whitebox in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from whiteboxgui->leafmap) (2.3.6)
#
# [notice] A new release of pip is available: 25.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import leafmap.foliumap as leafmap

# %% [markdown]
# Create a built-in draggable legend. Specify the output parameter to save the legend as an HTML file.

# %%
import os

# Save to home directory to avoid read-only file system issues
output_path = os.path.expanduser("~/NLCD_legend.html")

leafmap.create_legend(
    title="NLCD Land Cover Type",
    builtin_legend="NLCD",
    draggable=True,
    output=output_path,
)

#print(f"Legend saved to: {output_path}")
# Out:
# Legend saved to: /Users/haritshah/NLCD_legend.html

# %% [markdown]
# Create a built-in non-draggable legend. If the output parameter is not specified, the legend will be returned as an HTML string.

# %%
html = leafmap.create_legend(
    title="NLCD Land Cover Type",
    builtin_legend="NLCD",
    draggable=False,
    position="bottomright",
)

# %%
widget = leafmap.show_html(html)
widget
# Out:
# HTML(value='<!DOCTYPE html>\n<html lang="en">\n    <head> </head>\n    <body>\n        <div\n            id="m…

# %%
try:
    widget.close()
except:
    pass

# %% [markdown]
# Create a custom legend.

# %%
legend_dict = {
    "10 Trees": "006400",
    "20 Shrubland": "ffbb22",
    "30 Grassland": "ffff4c",
    "40 Cropland": "f096ff",
    "50 Built-up": "fa0000",
    "60 Barren / sparse vegetation": "b4b4b4",
    "70 Snow and ice": "f0f0f0",
    "80 Open water": "0064c8",
    "90 Herbaceous wetland": "0096a0",
    "95 Mangroves": "00cf75",
    "100 Moss and lichen": "fae6a0",
}

# %%
import os

# Save to home directory to avoid read-only file system issues
output_path = os.path.expanduser("~/ESA_legend.html")

leafmap.create_legend(
    title="ESA Land Cover Type",
    legend_dict=legend_dict,
    draggable=False,
    output=output_path,
)

#print(f"ESA Legend saved to: {output_path}")
# Out:
# ESA Legend saved to: /Users/haritshah/ESA_legend.html

# %% [markdown]
# Customize the legend by specifying the style parameter.

# %%
m = leafmap.Map()
m.add_basemap("ESA WorldCover 2021")

style = {
    "position": "fixed",
    "z-index": "9999",
    "border": "2px solid grey",
    "background-color": "rgba(255, 255, 255, 0.8)",
    "border-radius": "10px",
    "padding": "5px",
    "font-size": "14px",
    "bottom": "20px",
    "right": "5px",
}

m.add_legend(
    title="ESA Land Cover Type", legend_dict=legend_dict, draggable=False, style=style
)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac048393bae31c51b195a3ab2ad233ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac048393bae31c51b195a3ab2ad233ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac048393bae31c51b195a3ab2ad233ea = L.map(
#                 &quot;map_ac048393bae31c51b195a3ab2ad233ea&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_ac048393bae31c51b195a3ab2ad233ea);
#
#
#
#
#
#             var tile_layer_32b0b9c4506a285b236f9846ebcb7ff9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_32b0b9c4506a285b236f9846ebcb7ff9.addTo(map_ac048393bae31c51b195a3ab2ad233ea);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_ac048393bae31c51b195a3ab2ad233ea);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_49a60e3ef3db9fa235bbdda45f6f7ac6 = new L.featureGroup().addTo(
#                 map_ac048393bae31c51b195a3ab2ad233ea
#             );
#             options.edit.featureGroup = drawnItems_draw_control_49a60e3ef3db9fa235bbdda45f6f7ac6;
#             var draw_control_49a60e3ef3db9fa235bbdda45f6f7ac6 = new L.Control.Draw(
#                 options
#             ).addTo( map_ac048393bae31c51b195a3ab2ad233ea );
#             map_ac048393bae31c51b195a3ab2ad233ea.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_49a60e3ef3db9fa235bbdda45f6f7ac6.addLayer(layer);
#              });
#             map_ac048393bae31c51b195a3ab2ad233ea.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_49a60e3ef3db9fa235bbdda45f6f7ac6.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_8aa124e25c32bf8ed5d9986bbfad2db7 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_8aa124e25c32bf8ed5d9986bbfad2db7 = geocoderOpts_geocoder_8aa124e25c32bf8ed5d9986bbfad2db7[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_8aa124e25c32bf8ed5d9986bbfad2db7 = L.Control.Geocoder[ geocoderName_geocoder_8aa124e25c32bf8ed5d9986bbfad2db7 ](
#                 geocoderOpts_geocoder_8aa124e25c32bf8ed5d9986bbfad2db7[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_8aa124e25c32bf8ed5d9986bbfad2db7[&quot;geocoder&quot;] = customGeocoder_geocoder_8aa124e25c32bf8ed5d9986bbfad2db7;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_8aa124e25c32bf8ed5d9986bbfad2db7
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_8aa124e25c32bf8ed5d9986bbfad2db7[&#x27;zoom&#x27;] || map_ac048393bae31c51b195a3ab2ad233ea.getZoom();
#                 map_ac048393bae31c51b195a3ab2ad233ea.setView(e.geocode.center, zoom);
#             }).addTo(map_ac048393bae31c51b195a3ab2ad233ea);
#
#
#
#             map_ac048393bae31c51b195a3ab2ad233ea.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var macro_element_ef27f6737a1175bb0c9ff82a9f8ef3c4 = L.tileLayer.wms(
#                 &quot;https://services.terrascope.be/wms/v2&quot;,
#                 {&quot;attribution&quot;: &quot;ESA&quot;,

# %%
m = leafmap.Map()
m.add_basemap("ESA WorldCover 2021")
m.add_legend(title="ESA Land Cover Type", builtin_legend="ESA_WorldCover")
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8728d046fd57162a7c49cc0b98b416ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8728d046fd57162a7c49cc0b98b416ca&quot; &gt;&lt;/div&gt;
#
#
# &lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1&quot;&gt;
#   &lt;title&gt;jQuery UI Draggable - Default functionality&lt;/title&gt;
#   &lt;link rel=&quot;stylesheet&quot; href=&quot;//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css&quot;&gt;
#
#   &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.js&quot;&gt;&lt;/script&gt;
#   &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#
#   &lt;script&gt;
#   $( function() {
#     $( &quot;#maplegend&quot; ).draggable({
#                     start: function (event, ui) {
#                         $(this).css({
#                             right: &quot;auto&quot;,
#                             top: &quot;auto&quot;,
#                             bottom: &quot;auto&quot;
#                         });
#                     }
#                 });
# });
#
#   &lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div id=&#x27;maplegend&#x27; class=&#x27;maplegend&#x27;
#     style=&#x27;position: absolute; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
#      border-radius:6px; padding: 10px; font-size:14px; right: 20px; bottom: 20px;&#x27;&gt;
#
# &lt;div class=&#x27;legend-title&#x27;&gt;ESA Land Cover Type&lt;/div&gt;
# &lt;div class=&#x27;legend-scale&#x27;&gt;
#   &lt;ul class=&#x27;legend-labels&#x27;&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#006400;opacity:1.0;&#x27;&gt;&lt;/span&gt;10 Trees&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#ffbb22;opacity:1.0;&#x27;&gt;&lt;/span&gt;20 Shrubland&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#ffff4c;opacity:1.0;&#x27;&gt;&lt;/span&gt;30 Grassland&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#f096ff;opacity:1.0;&#x27;&gt;&lt;/span&gt;40 Cropland&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#fa0000;opacity:1.0;&#x27;&gt;&lt;/span&gt;50 Built-up&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#b4b4b4;opacity:1.0;&#x27;&gt;&lt;/span&gt;60 Barren / sparse vegetation&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#f0f0f0;opacity:1.0;&#x27;&gt;&lt;/span&gt;70 Snow and ice&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#0064c8;opacity:1.0;&#x27;&gt;&lt;/span&gt;80 Open water&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#0096a0;opacity:1.0;&#x27;&gt;&lt;/span&gt;90 Herbaceous wetland&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#00cf75;opacity:1.0;&#x27;&gt;&lt;/span&gt;95 Mangroves&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#fae6a0;opacity:1.0;&#x27;&gt;&lt;/span&gt;100 Moss and lichen&lt;/li&gt;
#   &lt;/ul&gt;
# &lt;/div&gt;
# &lt;/div&gt;
#
# &lt;/body&gt;
# &lt;/html&gt;
#
# &lt;style type=&#x27;text/css&#x27;&gt;
#   .maplegend .legend-title {
#     text-align: left;
#     margin-bottom: 5px;
#     font-weight: bold;
#     font-size: 90%;
#     }
#   .maplegend .legend-scale ul {
#     margin: 0;
#     margin-bottom: 5px;
#     padding: 0;
#     float: left;
#     list-style: none;
#     }
#   .maplegend .legend-scale ul li {
#     font-size: 80%;
#     list-style: none;
#     margin-left: 0;
#     line-height: 18px;
#     margin-bottom: 2px;
#     }
#   .maplegend ul.legend-labels li span {
#     display: block;
#     float: left;
#     height: 16px;
#     width: 30px;
#     margin-right: 5px;
#     margin-left: 0;
#     border: 1px solid #999;
#     }
#   .maplegend .legend-source {
#     font-size: 80%;
#     color: #777;
#     clear: both;
#     }
#   .maplegend a {
#     color: #777;
#     }
# &lt;/style&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8728d046fd57162a7c49cc0b98b416ca = L.map(
#                 &quot;map_8728d046fd57162a7c49cc0b98b416ca&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_8728d046fd57162a7c49cc0b98b416ca);
#
#
#
#
#
#             var tile_layer_433030c49d41b0f47999466d7e7a33af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;

# %% [markdown]
# Add legends to a split-view map. Make sure the draggable parameter is set to False.

# %%
m = leafmap.Map(
    center=[40, -100],
    zoom=4,
    draw_control=False,
    measure_control=False,
    scale_control=False,
)
m.split_map(left_layer="ESA WorldCover 2021", right_layer="NLCD 2019 CONUS Land Cover")
m.add_legend(
    title="ESA Land Cover Type",
    builtin_legend="ESA_WorldCover",
    draggable=False,
    position="bottomleft",
    style={"bottom": "5px"},
)
m.add_legend(
    title="NLCD Land Cover Type",
    builtin_legend="NLCD",
    draggable=False,
    position="bottomright",
)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d07639a83c5296aef87937bedb4015a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d07639a83c5296aef87937bedb4015a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d07639a83c5296aef87937bedb4015a = L.map(
#                 &quot;map_1d07639a83c5296aef87937bedb4015a&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawControl: false,
#                     measureControl: false,
#                     scaleControl: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_288e1c6b28d09f5190e002252103d35e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_288e1c6b28d09f5190e002252103d35e.addTo(map_1d07639a83c5296aef87937bedb4015a);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_1d07639a83c5296aef87937bedb4015a);
#
#
#
#             var geocoderOpts_geocoder_3c43257a5ec7e352ce80ecf491e4de8a = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_3c43257a5ec7e352ce80ecf491e4de8a = geocoderOpts_geocoder_3c43257a5ec7e352ce80ecf491e4de8a[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_3c43257a5ec7e352ce80ecf491e4de8a = L.Control.Geocoder[ geocoderName_geocoder_3c43257a5ec7e352ce80ecf491e4de8a ](
#                 geocoderOpts_geocoder_3c43257a5ec7e352ce80ecf491e4de8a[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_3c43257a5ec7e352ce80ecf491e4de8a[&quot;geocoder&quot;] = customGeocoder_geocoder_3c43257a5ec7e352ce80ecf491e4de8a;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_3c43257a5ec7e352ce80ecf491e4de8a
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_3c43257a5ec7e352ce80ecf491e4de8a[&#x27;zoom&#x27;] || map_1d07639a83c5296aef87937bedb4015a.getZoom();
#                 map_1d07639a83c5296aef87937bedb4015a.setView(e.geocode.center, zoom);
#             }).addTo(map_1d07639a83c5296aef87937bedb4015a);
#
#
#
#             map_1d07639a83c5296aef87937bedb4015a.fitBounds(
#                 [[40, -100], [40, -100]],
#                 {&quot;maxZoom&quot;: 4}
#             );
#
#
#             var macro_element_ef27f6737a1175bb0c9ff82a9f8ef3c4 = L.tileLayer.wms(
#                 &quot;https://services.terrascope.be/wms/v2&quot;,
#                 {&quot;attribution&quot;: &quot;ESA&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;WORLDCOVER_2021_MAP&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_ef27f6737a1175bb0c9ff82a9f8ef3c4.addTo(map_1d07639a83c5296aef87937bedb4015a);
#
#
#             var macro_element_4a69e4dc053251801c9d86e7e6a182a1 = L.tileLayer.wms(
#                 &quot;https://www.mrlc.gov/geoserver/mrlc_display/NLCD_2019_Land_Cover_L48/wms?&quot;,
#                 {&quot;attribution&quot;: &quot;MRLC&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;NLCD_2019_Land_Cover_L48&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_4a69e4dc053251801c9d86e7e6a182a1.addTo(map_1d07639a83c5296aef87937bedb4015a);
#
#
#             var side_by_side_layers_f00f1b39caf0f65f86a3d87595a368df = L.control.sideBySide(
#                 macro_element_ef27f6737a1175bb0c9ff82a9f8ef3c4, macro_element_4a69e4dc053251801c9d86e7e6a182a1
#             ).addTo(map_1d07639a83c5296aef87937bedb4015a);
#
#
#         L.Control.CustomControl = L.Control.extend({
#             onAdd: function(map) {
#                 let div = L.DomUtil.create(&#x27;div&#x27;);
#                 div.innerHTML = `&l
